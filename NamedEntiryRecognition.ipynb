# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
doc = nlp('Australia wants to force Facebook and Goolge to pay media companies for news')

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Australia 0 9 GPE
# Facebook 25 33 ORG
# Goolge 38 44 ORG

# %%
doc = nlp('I do not have money to pay my credit card account')

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

# %%
doc = nlp('what is the process to open a new savings account')

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

# %%
train = [
("Money transfer from my checking account is not working",{"entities":[(6,13,"ACTIVITY"),(23,39,"PRODUCT")]}),
("I want to check balance in my savings account",{"entities":[(16,23,"ACTIVITY"),(30,45,"PRODUCT")]}),
("I suscpect a fraud in my credit card account",{"entities":[(12,17,"ACTIVITY"),(24,35,"PRODUCT")]}),
("I am here for opening a new savings account",{"entities":[(14,21,"ACTIVITY"),(28,43,"PRODUCT")]}),
("Your mortgage is in delinquent status",{"entities":[(20,30,"ACTIVITY"),(5,13,"PRODUCT")]}),
("Your credit card is in past due date status",{"entities":[(23,31,"ACTIVITY"),(5,6,"PRODUCT")]}),
("My loan account is still not approved and funded",{"entities":[(25,37,"ACTIVITY"),(3,15,"PRODUCT"),(42,48,"ACTIVITY")]}),
("How do I open a new load account",{"entities":[(9,13,"ACTIVITY"),(20,32,"PRODUCT")]}),
("What are the charges on Investment account",{"entities":[(13,20,"ACTIVITY"),(24,42,"PRODUCT")]}),
("Can you explain late charges on credit card",{"entities":[(21,28,"ACTIVITY"),(35,46,"PRODUCT")]}),
("I want to open a new loan account",{"entities":[(10,14,"ACTIVITY"),(21,33,"PRODUCT")]}),
("Can you help updating payment on my credit card",{"entities":[(22,29,"ACTIVITY"),(36,47,"PRODUCT")]}),
("When is the payment due date on my card",{"entities":[(12,19,"ACTIVITY"),(35,39,"PRODUCT")]})
]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
ner = nlp.get_pipe('ner')

# %%
for _, annotations in train:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
disable_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# %%
with nlp.disable_pipes(*disable_pipes):
    optimizer = nlp.resume_training()
    
    for iteration in range(100):
        random.shuffle(train)
        losses = {}
        
        batches = minibatch(train, size = compounding(1.0, 4.0, 1.001))
        
        for batch in batches:
            text, annotation = zip(*batch)
            
            nlp.update(
                        text,
                        annotation,
                        drop=0.5,
                        losses=losses,
                        sgd=optimizer)
            print("Losses",losses)
# Out:
# Losses {'ner': 8.472044169902802}
# Losses {'ner': 13.1593635417521}
# Losses {'ner': 17.54206513168174}
# Losses {'ner': 24.239807027595816}
# Losses {'ner': 29.888043563085375}
# Losses {'ner': 35.68966389002162}
# F:\conda_env\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Can you explain late charges on credit card" with entities "[(21, 28, 'ACTIVITY'), (35, 46, 'PRODUCT')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# F:\conda_env\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "I suscpect a fraud in my credit card account" with entities "[(12, 17, 'ACTIVITY'), (24, 35, 'PRODUCT')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# Losses {'ner': 40.759943125515825}
# Losses {'ner': 47.613317461169196}
# Losses {'ner': 53.248984639949036}
# Losses {'ner': 59.97165842116518}
# Losses {'ner': 64.16190036839689}
# F:\conda_env\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Your credit card is in past due date status" with entities "[(23, 31, 'ACTIVITY'), (5, 6, 'PRODUCT')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# F:\conda_env\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Money transfer from my checking account is not wor..." with entities "[(6, 13, 'ACTIVITY'), (23, 39, 'PRODUCT')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# Losses {'ner': 69.47617834965567}
# Losses {'ner': 75.39004882143271}
# Losses {'ner': 6.47411981424375}
# Losses {'ner': 11.117508373931969}
# Losses {'ner': 15.15652308963331}
# Losses {'ner': 19.837631594167078}
# Losses {'ner': 25.10316578928473}
# Losses {'ner': 29.804478889247775}
# Losses {'ner': 36.073800004178565}
# Losses {'ner': 44.546964741403144}
# Losses {'ner': 49.337700298469144}
# Losses {'ner': 55.4922757705192}
# Losses {'ner': 59.15433051464947}
# Losses {'ner': 67.76618150691056}
# Losses {'ner': 72.38793166516834}
# Losses {'ner': 8.089413752779365}
# Losses {'ner': 11.6635287857207}
# Losses {'ner': 15.748622872546548}
# Losses {'ner': 18.474411978817415}
# Losses {'ner': 26.725818194581706}
# Losses {'ner': 31.88472029766305}
# Losses {'ner': 38.25683452388509}
# Losses {'ner': 44.20818093068178}
# Losses {'ner': 48.82690587031388}
# Losses {'ner': 55.22947634287843}
# Losses {'ner': 61.376499910211706}
# Losses {'ner': 68.04179007776692}
# Losses {'ner': 71.47160551893411}
# Losses {'ner': 5.128768083193279}
# Losses {'ner': 11.955968235173202}
# Losses {'ner': 16.94675670729106}
# Losses {'ner': 22.289877334396294}
# Losses {'ner': 29.919044660656652}
# Losses {'ner': 38.921697663395605}
# Losses {'ner': 45.4463880962125}
# Losses {'ner': 52.22289460968608}
# Losses {'ner': 60.150718034025374}
# Losses {'ner': 63.64543794708692}
# Losses {'ner': 65.19932721868206}
# Losses {'ner': 71.71119661942173}
# Losses {'ner': 76.89260067771481}
# Losses {'ner': 7.536885306239128}
# Losses {'ner': 14.582559004426003}
# Losses {'ner': 18.353608065233857}
# Losses {'ner': 24.277886583418876}
# Losses {'ner': 29.425371068478853}
# Losses {'ner': 34.446939142137126}
# Losses {'ner': 41.86460670206725}
# Losses {'ner': 48.351577005647414}
# Losses {'ner': 56.59339846414696}
# Losses {'ner': 65.20373724238198}
# Losses {'ner': 69.47807081439714}
# Losses {'ner': 75.27251777270911}
# Losses {'ner': 79.69932331176577}
# Losses {'ner': 3.309737864881754}
# Losses {'ner': 7.5474253905704245}
# Losses {'ner': 10.594929397356282}
# Losses {'ner': 18.851561814796696}
# Losses {'ner': 26.194355368864308}
# Losses {'ner': 32.55012755493499}
# Losses {'ner': 39.46046955163456}
# Losses {'ner': 45.411594949912796}
# Losses {'ner': 54.74477433438278}
# Losses {'ner': 58.093643623530625}
# Losses {'ner': 64.6392439782021}
# Losses {'ner': 72.45974277764162}
# Losses {'ner': 79.70951392188272}
# Losses {'ner': 4.97623828612268}
# Losses {'ner': 12.52922416292131}
# Losses {'ner': 16.585066387429833}
# Losses {'ner': 21.530290780356154}
# Losses {'ner': 23.46845231562338}
# Losses {'ner': 30.37863811462603}
# Losses {'ner': 34.5971709587086}
# Losses {'ner': 38.85604209686085}
# Losses {'ner': 42.98178217733607}
# Losses {'ner': 51.25328922445283}
# Losses {'ner': 59.486701490230416}
# Losses {'ner': 65.36588789323673}
# Losses {'ner': 71.73341813360844}
# Losses {'ner': 6.865075334924768}
# Losses {'ner': 16.779209956544946}
# Losses {'ner': 23.095475932077534}
# Losses {'ner': 30.289536687971122}
# Losses {'ner': 35.97826357880331}
# Losses {'ner': 41.174040472123124}
# Losses {'ner': 47.20194718799303}
# Losses {'ner': 52.11942449672108}
# Losses {'ner': 57.86770111037379}
# Losses {'ner': 62.1713529999771}
# Losses {'ner': 67.01708907291425}
# Losses {'ner': 71.50105488702786}
# Losses {'ner': 77.65165922247536}
# Losses {'ner': 5.288169488310814}
# Losses {'ner': 12.169602547328395}
# Losses {'ner': 19.627094818816545}
# Losses {'ner': 22.082375250886685}
# Losses {'ner': 27.356244780253178}
# Losses {'ner': 34.899470785995504}
# Losses {'ner': 39.10776593681919}
# Losses {'ner': 48.37498244043934}
# Losses {'ner': 53.001788532252135}
# Losses {'ner': 61.05649382583931}
# Losses {'ner': 66.31767151327938}
# Losses {'ner': 73.70515367956966}
# Losses {'ner': 80.0567475383067}
# Losses {'ner': 9.321637704968452}
# Losses {'ner': 16.63937632739544}
# Losses {'ner': 21.470078418791672}
# Losses {'ner': 27.364961580668023}
# Losses {'ner': 33.09584649253884}
# Losses {'ner': 41.027727671909815}
# Losses {'ner': 48.894226655205784}
# Losses {'ner': 54.19423288882717}
# Losses {'ner': 60.840180287357725}
# Losses {'ner': 67.65084887868943}
# Losses {'ner': 70.02353037493658}
# Losses {'ner': 75.9611122717185}
# Losses {'ner': 81.08816093149717}
# Losses {'ner': 7.191250909818336}
# Losses {'ner': 15.592238653684035}
# Losses {'ner': 20.168551274098718}
# Losses {'ner': 22.812066535127087}
# Losses {'ner': 30.48255067576264}
# Losses {'ner': 37.17895206373959}
# Losses {'ner': 42.31653600298176}
# Losses {'ner': 49.29358399479696}
# Losses {'ner': 54.71265777300158}
# Losses {'ner': 61.73294731664823}
# Losses {'ner': 66.97194755620325}
# Losses {'ner': 71.25933916001978}
# Losses {'ner': 76.95265198379221}
# Losses {'ner': 6.3242189404554665}
# Losses {'ner': 7.823739530795137}
# Losses {'ner': 13.16271440339915}
# Losses {'ner': 18.05352880647115}
# Losses {'ner': 22.722563616654952}
# Losses {'ner': 30.520770048737177}
# Losses {'ner': 35.02519262766873}
# Losses {'ner': 41.98732715396909}
# Losses {'ner': 44.8254914481804}
# Losses {'ner': 51.87519719291595}
# Losses {'ner': 61.29486187387374}
# Losses {'ner': 67.53203694176045}
# Losses {'ner': 72.42170362264005}
# Losses {'ner': 4.969152923673391}
# Losses {'ner': 10.622508892789483}
# Losses {'ner': 19.690425673499703}
# Losses {'ner': 29.45344420010224}
# Losses {'ner': 36.05271220067516}
# Losses {'ner': 42.922903904048724}
# Losses {'ner': 46.689777714489026}
# Losses {'ner': 53.578047161279244}
# Losses {'ner': 61.64455635967664}
# Losses {'ner': 67.78543041093275}
# Losses {'ner': 72.68943435331806}
# Losses {'ner': 80.3215537418559}
# Losses {'ner': 84.97059591421333}
# Losses {'ner': 8.494920917320997}
# Losses {'ner': 13.793026608629589}
# Losses {'ner': 18.82231060155391}
# Losses {'ner': 22.823587165464232}
# Losses {'ner': 30.162789903831253}
# Losses {'ner': 39.45147415275551}
# Losses {'ner': 45.793336489255125}
# Losses {'ner': 51.534113922173674}
# Losses {'ner': 57.03015634139865}
# Losses {'ner': 63.13260921278834}
# Losses {'ner': 70.1416369907115}
# Losses {'ner': 71.84412269571521}
# Losses {'ner': 78.1588464798192}
# Losses {'ner': 3.0705356605631096}
# Losses {'ner': 8.520712297484351}
# Losses {'ner': 15.109103996381236}
# Losses {'ner': 19.25928272686906}
# Losses {'ner': 25.64899457626052}
# Losses {'ner': 30.07818008039976}
# Losses {'ner': 33.969797400877724}
# Losses {'ner': 39.82886440505172}
# Losses {'ner': 48.13679374207641}
# Losses {'ner': 55.36873410095359}
# Losses {'ner': 61.45082283998954}
# Losses {'ner': 67.70075075715295}
# Losses {'ner': 72.23831983216087}
# Losses {'ner': 7.000346133485436}
# Losses {'ner': 14.050130298830481}
# Losses {'ner': 17.795350514530647}
# Losses {'ner': 20.647353529700986}
# Losses {'ner': 25.93470484407232}
# Losses {'ner': 27.65830369340626}
# Losses {'ner': 31.147420539291552}
# Losses {'ner': 34.12922406080549}
# Losses {'ner': 40.67597559952946}
# Losses {'ner': 44.87708638696403}
# Losses {'ner': 51.33628121815763}
# Losses {'ner': 59.66883061133466}
# Losses {'ner': 65.42427563881483}
# Losses {'ner': 4.462893478787009}
# Losses {'ner': 10.454110514587228}
# Losses {'ner': 17.371826589322154}
# Losses {'ner': 22.186792546572846}
# Losses {'ner': 28.954377666969535}
# Losses {'ner': 35.527140985165474}
# Losses {'ner': 42.67266509541513}
# Losses {'ner': 48.38561192014457}
# Losses {'ner': 51.01696139463486}
# Losses {'ner': 61.23605596541013}
# Losses {'ner': 65.65623152359906}
# Losses {'ner': 71.9073137055296}
# Losses {'ner': 78.61683048542064}
# Losses {'ner': 6.948629446327686}
# Losses {'ner': 14.905256994068623}
# Losses {'ner': 17.239762697805418}
# Losses {'ner': 23.446412194956793}
# Losses {'ner': 26.924745781783713}
# Losses {'ner': 33.13762250027503}
# Losses {'ner': 40.860131169174565}
# Losses {'ner': 45.01481614510567}
# Losses {'ner': 49.208639910603324}
# Losses {'ner': 54.695328908199826}
# Losses {'ner': 59.506046285978755}
# Losses {'ner': 67.36808448111196}
# Losses {'ner': 74.20364344737982}
# Losses {'ner': 8.142758719623089}
# Losses {'ner': 14.144021920859814}
# Losses {'ner': 22.112933687865734}
# Losses {'ner': 26.832423340786363}
# Losses {'ner': 30.398745821740476}
# Losses {'ner': 38.20750875952467}
# Losses {'ner': 45.62433594646677}
# Losses {'ner': 53.21500656190142}
# Losses {'ner': 61.19506415906176}
# Losses {'ner': 64.97455361585412}
# Losses {'ner': 70.38419428430166}
# Losses {'ner': 77.8173420127448}
# Losses {'ner': 80.0558593471676}
# Losses {'ner': 5.702349968254566}
# Losses {'ner': 13.514469872694463}
# Losses {'ner': 20.748752291779965}
# Losses {'ner': 26.2217931705527}
# Losses {'ner': 30.08036761409312}
# Losses {'ner': 37.39171215200622}
# Losses {'ner': 44.34873784352385}
# Losses {'ner': 48.8330925602495}
# Losses {'ner': 55.08311032196798}
# Losses {'ner': 57.158050473484764}
# Losses {'ner': 61.48803733367458}
# Losses {'ner': 68.20485578555599}
# Losses {'ner': 71.52469494901379}
# Losses {'ner': 7.533872526139021}
# Losses {'ner': 15.9480094127357}
# Losses {'ner': 24.076510440558195}
# Losses {'ner': 30.397188188275322}
# Losses {'ner': 37.40970432921313}
# Losses {'ner': 45.039995548082516}
# Losses {'ner': 53.703543429030105}
# Losses {'ner': 59.22239333833568}
# Losses {'ner': 63.70739818341099}
# Losses {'ner': 69.00036474341199}
# Losses {'ner': 75.5015814111945}
# Losses {'ner': 78.79473749527064}
# Losses {'ner': 81.8235305014417}
# Losses {'ner': 6.396002678017222}
# Losses {'ner': 12.143195120434367}
# Losses {'ner': 17.238848542611205}
# Losses {'ner': 22.91363254869645}
# Losses {'ner': 31.050791955835276}
# Losses {'ner': 39.388244559805}
# Losses {'ner': 43.99649633898423}
# Losses {'ner': 50.52694699599431}
# Losses {'ner': 55.830896163520606}
# Losses {'ner': 62.11113841289023}
# Losses {'ner': 67.42755790711715}
# Losses {'ner': 73.76589814485385}
# Losses {'ner': 79.78486752189099}
# Losses {'ner': 7.787548232819063}
# Losses {'ner': 14.238562605196421}
# Losses {'ner': 21.504230997377817}
# Losses {'ner': 25.049673495666866}
# Losses {'ner': 29.25418716693639}
# Losses {'ner': 35.350181141073335}
# Losses {'ner': 43.448449858600725}
# Losses {'ner': 46.941391521294065}
# Losses {'ner': 56.440116160709806}
# Losses {'ner': 59.97482891963608}
# Losses {'ner': 64.50552867935784}
# Losses {'ner': 73.31258570240624}
# Losses {'ner': 79.10699527451669}
# Losses {'ner': 5.754506257876528}
# Losses {'ner': 14.051714703023208}
# Losses {'ner': 20.628985568463577}
# Losses {'ner': 26.5392392273543}
# Losses {'ner': 34.96470912224777}
# Losses {'ner': 41.31905565421539}
# Losses {'ner': 48.721086286115224}
# Losses {'ner': 52.8087031153168}
# Losses {'ner': 57.00176390783372}
# Losses {'ner': 62.499693839197334}
# Losses {'ner': 67.14359881251357}
# Losses {'ner': 72.93329115689039}
# Losses {'ner': 77.04125955727022}
# Losses {'ner': 3.6569847033816814}
# Losses {'ner': 12.037356925894642}
# Losses {'ner': 19.81391326791629}
# Losses {'ner': 22.423151001039628}
# Losses {'ner': 28.64248464972127}
# Losses {'ner': 36.40613551868239}
# Losses {'ner': 41.35457172992403}
# Losses {'ner': 49.27925993504698}
# Losses {'ner': 51.72870937551136}
# Losses {'ner': 56.846887020419786}
# Losses {'ner': 64.44184955770845}
# Losses {'ner': 65.76681732408701}
# Losses {'ner': 70.97117500960462}
# Losses {'ner': 8.23570435271381}
# Losses {'ner': 14.797103454924809}
# Losses {'ner': 24.39812483268227}
# Losses {'ner': 27.668911661684007}
# Losses {'ner': 36.59046862366861}
# Losses {'ner': 45.45897735002703}
# Losses {'ner': 50.85256467670857}
# Losses {'ner': 57.82927136034428}
# Losses {'ner': 64.55742137045323}
# Losses {'ner': 68.87131942299183}
# Losses {'ner': 76.17009278622444}
# Losses {'ner': 83.44024481859978}
# Losses {'ner': 88.6820903803733}
# Losses {'ner': 7.312278017401695}
# Losses {'ner': 13.020469672977924}
# Losses {'ner': 18.884714100509882}
# Losses {'ner': 22.219696398824453}
# Losses {'ner': 28.323408396332525}
# Losses {'ner': 33.262424926435415}
# Losses {'ner': 39.54617384192716}
# Losses {'ner': 44.577030389920765}
# Losses {'ner': 52.06845454068571}
# Losses {'ner': 59.36531071679383}
# Losses {'ner': 64.34570900013387}
# Losses {'ner': 69.35888196469932}
# Losses {'ner': 75.87951686489578}
# Losses {'ner': 4.31522323024565}
# Losses {'ner': 9.252939853000683}
# Losses {'ner': 15.596257272291226}
# Losses {'ner': 19.212343271994726}
# Losses {'ner': 22.62984541751048}
# Losses {'ner': 27.502439431349742}
# Losses {'ner': 33.887302010357914}
# Losses {'ner': 38.33421926930309}
# Losses {'ner': 45.280292796419914}
# Losses {'ner': 53.12372018628007}
# Losses {'ner': 55.68250827925162}
# Losses {'ner': 65.27280347483115}
# Losses {'ner': 70.76479088346473}
# Losses {'ner': 3.1097684277920052}
# Losses {'ner': 12.530581392231397}
# Losses {'ner': 16.465544989710907}
# Losses {'ner': 24.501351287966827}
# Losses {'ner': 28.524108896909638}
# Losses {'ner': 34.33632762817888}
# Losses {'ner': 39.27436556327211}
# Losses {'ner': 46.43836692846435}
# Losses {'ner': 50.883928053407544}
# Losses {'ner': 54.65178286635546}
# Losses {'ner': 61.10349834403951}
# Losses {'ner': 65.65367732449431}
# Losses {'ner': 72.05810559793372}
# Losses {'ner': 9.083456873893738}
# Losses {'ner': 15.870036844164133}
# Losses {'ner': 19.572463846910978}
# Losses {'ner': 26.429645245108986}
# Losses {'ner': 33.31609547618427}
# Losses {'ner': 41.24964792295941}
# Losses {'ner': 46.758139895653585}
# Losses {'ner': 54.64893628880964}
# Losses {'ner': 62.654203014826635}
# Losses {'ner': 66.99975938061834}
# Losses {'ner': 72.86892546052695}
# Losses {'ner': 81.07941851849318}
# Losses {'ner': 85.84596898280142}
# Losses {'ner': 8.868404895067215}
# Losses {'ner': 14.627837625332177}
# Losses {'ner': 17.644684109640366}
# Losses {'ner': 25.816697797428986}
# Losses {'ner': 29.485659494396003}
# Losses {'ner': 35.54311601240917}
# Losses {'ner': 42.400035911992035}
# Losses {'ner': 48.95462881010755}
# Losses {'ner': 57.46651520748421}
# Losses {'ner': 60.314004046750796}
# Losses {'ner': 63.28923154007791}
# Losses {'ner': 70.44456328076669}
# Losses {'ner': 78.66050400209971}
# Losses {'ner': 8.338377445936203}
# Losses {'ner': 11.538671507092658}
# Losses {'ner': 17.909894774260465}
# Losses {'ner': 25.84019782632822}
# Losses {'ner': 32.226143373151444}
# Losses {'ner': 38.77996517529073}
# Losses {'ner': 45.266891956304335}
# Losses {'ner': 51.31345705854705}
# Losses {'ner': 56.535993413804086}
# Losses {'ner': 62.94198969813528}
# Losses {'ner': 68.97915193517923}
# Losses {'ner': 72.47574397970396}
# Losses {'ner': 80.78228831340033}
# Losses {'ner': 5.25239656301801}
# Losses {'ner': 11.125534156287358}
# Losses {'ner': 18.458945249468343}
# Losses {'ner': 25.398895208984868}
# Losses {'ner': 31.55339782070314}
# Losses {'ner': 37.41714275758659}
# Losses {'ner': 41.84695181263851}
# Losses {'ner': 48.65945906205343}
# Losses {'ner': 57.328109091238815}
# Losses {'ner': 61.93096207129392}
# Losses {'ner': 69.29065184342298}
# Losses {'ner': 75.46554743685383}
# Losses {'ner': 83.79232528151451}
# Losses {'ner': 7.764674544334412}
# Losses {'ner': 15.54173683318368}
# Losses {'ner': 21.649334616391574}
# Losses {'ner': 27.730695969788943}
# Losses {'ner': 33.20981790655969}
# Losses {'ner': 37.73726188959881}
# Losses {'ner': 46.42880165400311}
# Losses {'ner': 51.70382109107777}
# Losses {'ner': 55.70624983216294}
# Losses {'ner': 62.526817485935624}
# Losses {'ner': 69.66138242350218}
# Losses {'ner': 76.14230911325404}
# Losses {'ner': 81.71188629729414}
# Losses {'ner': 6.923233985900879}
# Losses {'ner': 8.908251065411605}
# Losses {'ner': 12.38221361527394}
# Losses {'ner': 15.349647088736674}
# Losses {'ner': 21.043301569923642}
# Losses {'ner': 27.13782009458555}
# Losses {'ner': 34.27327904081358}
# Losses {'ner': 42.72562551660849}
# Losses {'ner': 47.57267451514235}
# Losses {'ner': 52.798083458978}
# Losses {'ner': 59.23675601645118}
# Losses {'ner': 66.81178348247522}
# Losses {'ner': 71.42384008592671}
# Losses {'ner': 6.378862789420964}
# Losses {'ner': 14.54460609212174}
# Losses {'ner': 20.033564272072454}
# Losses {'ner': 28.057087461611218}
# Losses {'ner': 37.33712617602009}
# Losses {'ner': 40.75204492735725}
# Losses {'ner': 46.358333807467034}
# Losses {'ner': 53.88134535777431}
# Losses {'ner': 62.246951039908936}
# Losses {'ner': 67.49531013148885}
# Losses {'ner': 76.6758060641871}
# Losses {'ner': 81.58171965987935}
# Losses {'ner': 85.29759768426561}
# Losses {'ner': 7.278599964316527}
# Losses {'ner': 10.859528529086674}
# Losses {'ner': 17.89535385876843}
# Losses {'ner': 25.709682374903423}
# Losses {'ner': 30.10143973994309}
# Losses {'ner': 36.85786139293123}
# Losses {'ner': 43.02883219188516}
# Losses {'ner': 46.48746297915204}
# Losses {'ner': 51.724309139295656}
# Losses {'ner': 57.623399906202394}
# Losses {'ner': 68.13511275534256}
# Losses {'ner': 72.74001371254474}
# Losses {'ner': 80.38690396537334}
# Losses {'ner': 8.582646483555436}
# Losses {'ner': 14.323340190574527}
# Losses {'ner': 20.012888127705082}
# Losses {'ner': 26.22871086723171}
# Losses {'ner': 33.94518837191572}
# Losses {'ner': 39.43075133905222}
# Losses {'ner': 45.756141136735096}
# Losses {'ner': 51.13330891109945}
# Losses {'ner': 60.10446711756231}
# Losses {'ner': 62.86421685467303}
# Losses {'ner': 69.79936589847148}
# Losses {'ner': 75.93413831840098}
# Losses {'ner': 83.64162595371545}
# Losses {'ner': 8.714473992586136}
# Losses {'ner': 12.826817546505481}
# Losses {'ner': 17.583049465369186}
# Losses {'ner': 25.937013345237574}
# Losses {'ner': 31.222883259074592}
# Losses {'ner': 39.97294542671909}
# Losses {'ner': 43.646806425503314}
# Losses {'ner': 49.488611508714826}
# Losses {'ner': 54.486707691657216}
# Losses {'ner': 60.655159612099965}
# Losses {'ner': 65.82377913988705}
# Losses {'ner': 71.64609675642089}
# Losses {'ner': 78.01648925471113}
# Losses {'ner': 5.705437242984772}
# Losses {'ner': 9.105699859031489}
# Losses {'ner': 13.955868827786077}
# Losses {'ner': 21.583116831864942}
# Losses {'ner': 29.124609685178626}
# Losses {'ner': 34.37744508092456}
# Losses {'ner': 39.108824835300226}
# Losses {'ner': 49.14703141260125}
# Losses {'ner': 54.14371692839646}
# Losses {'ner': 61.130576875839466}
# Losses {'ner': 64.73893310125564}
# Losses {'ner': 69.3962608598114}
# Losses {'ner': 77.00494610042657}
# Losses {'ner': 6.053776358544383}
# Losses {'ner': 10.27778952783683}
# Losses {'ner': 18.985739881459267}
# Losses {'ner': 23.489384377661736}
# Losses {'ner': 29.17366089979896}
# Losses {'ner': 35.699201382575666}
# Losses {'ner': 42.38024032848898}
# Losses {'ner': 47.62822743516426}
# Losses {'ner': 56.29022618394356}
# Losses {'ner': 61.480770937548186}
# Losses {'ner': 70.95751630459836}
# Losses {'ner': 76.09235820864251}
# Losses {'ner': 79.95206098669132}
# Losses {'ner': 4.918413151055574}
# Losses {'ner': 9.200419774299192}
# Losses {'ner': 12.122181910081808}
# Losses {'ner': 17.28644408377916}
# Losses {'ner': 24.471765899091068}
# Losses {'ner': 31.647276402442756}
# Losses {'ner': 36.447939195661846}
# Losses {'ner': 41.38164000373173}
# Losses {'ner': 47.60088975887585}
# Losses {'ner': 53.4420733058064}
# Losses {'ner': 57.168359087243076}
# Losses {'ner': 64.33739607168674}
# Losses {'ner': 69.2040663644889}
# Losses {'ner': 6.282975554466248}
# Losses {'ner': 12.5491062803045}
# Losses {'ner': 17.033676202859738}
# Losses {'ner': 22.636188748743393}
# Losses {'ner': 24.476584724236034}
# Losses {'ner': 31.507671228695415}
# Losses {'ner': 39.65696250562718}
# Losses {'ner': 47.10219066505482}
# Losses {'ner': 52.798254131424926}
# Losses {'ner': 59.09870251695787}
# Losses {'ner': 66.81634923498308}
# Losses {'ner': 73.78178603273221}
# Losses {'ner': 80.99673946482466}
# Losses {'ner': 5.1410221345722675}
# Losses {'ner': 11.362760414368267}
# Losses {'ner': 15.879000564570333}
# Losses {'ner': 24.00427724933138}
# Losses {'ner': 29.391562235540505}
# Losses {'ner': 36.82133184184818}
# Losses {'ner': 41.68331540292161}
# Losses {'ner': 47.481749831792285}
# Losses {'ner': 52.2311871555637}
# Losses {'ner': 61.33475007684933}
# Losses {'ner': 67.45273678098488}
# Losses {'ner': 73.5401097913334}
# Losses {'ner': 78.22690295748794}
# Losses {'ner': 6.874752044677734}
# Losses {'ner': 12.550321252565482}
# Losses {'ner': 19.84743082911882}
# Losses {'ner': 26.488830357018742}
# Losses {'ner': 33.89648441610916}
# Losses {'ner': 40.42592690711899}
# Losses {'ner': 48.40677754407807}
# Losses {'ner': 53.86665509468003}
# Losses {'ner': 61.10956671660824}
# Losses {'ner': 68.96484222834988}
# Losses {'ner': 73.35300420203725}
# Losses {'ner': 80.17103950658361}
# Losses {'ner': 86.39748541989843}
# Losses {'ner': 4.579645468969829}
# Losses {'ner': 10.479691694607027}
# Losses {'ner': 17.732329796184786}
# Losses {'ner': 24.072090855317583}
# Losses {'ner': 29.131365958730385}
# Losses {'ner': 37.12383887557189}
# Losses {'ner': 43.29474592221777}
# Losses {'ner': 51.156734109054014}
# Losses {'ner': 58.66374611867468}
# Losses {'ner': 65.05464101036887}
# Losses {'ner': 71.53490808805327}
# Losses {'ner': 77.12468314959187}
# Losses {'ner': 81.86886875467826}
# Losses {'ner': 5.5776197463274}
# Losses {'ner': 10.039141560031567}
# Losses {'ner': 14.390837765569131}
# Losses {'ner': 23.02842122250263}
# Losses {'ner': 29.65504096382324}
# Losses {'ner': 33.941709538609985}
# Losses {'ner': 40.67982517471796}
# Losses {'ner': 50.36043213596827}
# Losses {'ner': 55.884871128110944}
# Losses {'ner': 62.85540333080394}
# Losses {'ner': 68.46422120390946}
# Losses {'ner': 75.12442868446544}
# Losses {'ner': 80.91828339778897}
# Losses {'ner': 8.206503883004189}
# Losses {'ner': 13.158772047193196}
# Losses {'ner': 20.717490639121678}
# Losses {'ner': 28.373584460051205}
# Losses {'ner': 34.347504325726476}
# Losses {'ner': 40.407439597466436}
# Losses {'ner': 47.652150132277455}
# Losses {'ner': 51.08862610501612}
# Losses {'ner': 56.28168775455353}
# Losses {'ner': 62.611348661941264}
# Losses {'ner': 66.77217004029146}
# Losses {'ner': 71.95930087892404}
# Losses {'ner': 79.1243392261683}
# Losses {'ner': 8.272089570760727}
# Losses {'ner': 14.281722350686323}
# Losses {'ner': 19.27694835298462}
# Losses {'ner': 25.06900248111924}
# Losses {'ner': 31.2037619780167}
# Losses {'ner': 36.90466414128423}
# Losses {'ner': 43.516404342995884}
# Losses {'ner': 48.43397397770423}
# Losses {'ner': 56.38999828173655}
# Losses {'ner': 59.65477936192292}
# Losses {'ner': 62.66001639897695}
# Losses {'ner': 65.61985973711353}
# Losses {'ner': 72.40309445500543}
# Losses {'ner': 4.054932532000294}
# Losses {'ner': 10.027330701338997}
# Losses {'ner': 14.47484792185196}
# Losses {'ner': 17.73208055789064}
# Losses {'ner': 22.292375476606594}
# Losses {'ner': 30.835329146631466}
# Losses {'ner': 37.06556419426988}
# Losses {'ner': 42.41108976960595}
# Losses {'ner': 44.689569651838156}
# Losses {'ner': 48.85646168243602}
# Losses {'ner': 54.758209758517296}
# Losses {'ner': 59.91752697687616}
# Losses {'ner': 67.31913191240301}
# Losses {'ner': 3.606494872994517}
# Losses {'ner': 8.873152455944364}
# Losses {'ner': 16.649946248788183}
# Losses {'ner': 22.521092843137012}
# Losses {'ner': 26.272763834323996}
# Losses {'ner': 29.552347936656588}
# Losses {'ner': 35.82196411260975}
# Losses {'ner': 42.28109416881216}
# Losses {'ner': 47.62281156758468}
# Losses {'ner': 55.4458001969258}
# Losses {'ner': 59.21229897353692}
# Losses {'ner': 65.96746651860553}
# Losses {'ner': 72.34569584885844}
# Losses {'ner': 8.365682661533356}
# Losses {'ner': 15.831853789277375}
# Losses {'ner': 19.463043958574417}
# Losses {'ner': 22.10907046966895}
# Losses {'ner': 29.411266584924306}
# Losses {'ner': 36.77621347643435}
# Losses {'ner': 38.82218074501725}
# Losses {'ner': 44.34873304951179}
# Losses {'ner': 50.45044730666268}
# Losses {'ner': 57.397545185813215}
# Losses {'ner': 63.46587510229766}
# Losses {'ner': 70.6264057663244}
# Losses {'ner': 76.75187652925125}
# Losses {'ner': 2.9273220843315357}
# Losses {'ner': 8.86263261946442}
# Losses {'ner': 13.141014094209822}
# Losses {'ner': 19.491449506815115}
# Losses {'ner': 26.726514684109134}
# Losses {'ner': 32.633391644994845}
# Losses {'ner': 38.976931717435946}
# Losses {'ner': 47.02951877955638}
# Losses {'ner': 51.094191033915195}
# Losses {'ner': 52.14874841916216}
# Losses {'ner': 58.030514178602814}
# Losses {'ner': 61.802279991563026}
# Losses {'ner': 68.82109193270988}
# Losses {'ner': 3.1602726166129287}
# Losses {'ner': 8.283570787792996}
# Losses {'ner': 13.390766306703881}
# Losses {'ner': 20.306529322811073}
# Losses {'ner': 25.625886707824137}
# Losses {'ner': 31.55751676790085}
# Losses {'ner': 40.7763595821353}
# Losses {'ner': 48.80125718491142}
# Losses {'ner': 57.69499485867088}
# Losses {'ner': 62.943070181850246}
# Losses {'ner': 69.83906394915645}
# Losses {'ner': 77.20363694343636}
# Losses {'ner': 81.73492970778629}
# Losses {'ner': 5.7492371797561646}
# Losses {'ner': 9.885620914058563}
# Losses {'ner': 15.697650356178201}
# Losses {'ner': 22.42912263232938}
# Losses {'ner': 29.84609609628751}
# Losses {'ner': 34.0858603955312}
# Losses {'ner': 41.34947677860691}
# Losses {'ner': 46.69835862014634}
# Losses {'ner': 53.59315080810529}
# Losses {'ner': 60.14651936534983}
# Losses {'ner': 64.57464459408266}
# Losses {'ner': 71.58364592362386}
# Losses {'ner': 74.60352933467811}
# Losses {'ner': 4.060790897114202}
# Losses {'ner': 10.902302767848596}
# Losses {'ner': 16.294988651138056}
# Losses {'ner': 22.732972069431185}
# Losses {'ner': 25.712799834799284}
# Losses {'ner': 29.819054921786915}
# Losses {'ner': 32.23153485467253}
# Losses {'ner': 37.93012699594317}
# Losses {'ner': 46.828349501989464}
# Losses {'ner': 51.2498484852689}
# Losses {'ner': 56.85736173418934}
# Losses {'ner': 62.913893627133234}
# Losses {'ner': 67.00413311054524}
# Losses {'ner': 5.128262042999268}
# Losses {'ner': 11.479984939098358}
# Losses {'ner': 17.705287578864954}
# Losses {'ner': 26.12163964228239}
# Losses {'ner': 29.018431184231304}
# Losses {'ner': 35.60999008361978}
# Losses {'ner': 40.89515146478516}
# Losses {'ner': 43.97904390334588}
# Losses {'ner': 50.71367123215896}
# Losses {'ner': 53.54798479330202}
# Losses {'ner': 57.76197580861472}
# Losses {'ner': 67.74735800790214}
# Losses {'ner': 72.05790417509698}
# Losses {'ner': 5.667163095129155}
# Losses {'ner': 10.639485588920735}
# Losses {'ner': 16.60690047410801}
# Losses {'ner': 21.262683196044712}
# Losses {'ner': 26.618135748482494}
# Losses {'ner': 33.550430176831036}
# Losses {'ner': 39.74398516447163}
# Losses {'ner': 46.49649699360943}
# Losses {'ner': 51.565693853578196}
# Losses {'ner': 58.26347571135797}
# Losses {'ner': 63.75904797622849}
# Losses {'ner': 70.4908058107822}
# Losses {'ner': 73.05401005879418}
# Losses {'ner': 5.775855195352278}
# Losses {'ner': 10.42867687774583}
# Losses {'ner': 15.803117175758612}
# Losses {'ner': 19.238896492713845}
# Losses {'ner': 25.919990724646848}
# Losses {'ner': 29.11700867185871}
# Losses {'ner': 32.64018307271786}
# Losses {'ner': 39.62740727718361}
# Losses {'ner': 44.75712661291496}
# Losses {'ner': 51.04905799622671}
# Losses {'ner': 57.26917018587724}
# Losses {'ner': 61.465248707556924}
# Losses {'ner': 65.40095202213988}
# Losses {'ner': 4.553458224632777}
# Losses {'ner': 8.658225243198956}
# Losses {'ner': 12.731072725392966}
# Losses {'ner': 16.391736337579875}
# Losses {'ner': 22.69267053309837}
# Losses {'ner': 27.32869291146149}
# Losses {'ner': 33.61472462447223}
# Losses {'ner': 36.44433380326832}
# Losses {'ner': 44.29879511556233}
# Losses {'ner': 52.00881100854481}
# Losses {'ner': 55.9649609208595}
# Losses {'ner': 63.68415695731751}
# Losses {'ner': 66.8507385143334}
# Losses {'ner': 5.363645575940609}
# Losses {'ner': 8.561014326164496}
# Losses {'ner': 14.477661995110587}
# Losses {'ner': 18.05497590347911}
# Losses {'ner': 26.650824866143715}
# Losses {'ner': 31.716422581288064}
# Losses {'ner': 39.74338097235843}
# Losses {'ner': 46.611271479341234}
# Losses {'ner': 52.18611947557613}
# Losses {'ner': 57.60847060869812}
# Losses {'ner': 65.06631386767506}
# Losses {'ner': 68.30715730808035}
# Losses {'ner': 70.88075706758966}
# Losses {'ner': 5.35725783988164}
# Losses {'ner': 11.349636762060982}
# Losses {'ner': 17.989399334067002}
# Losses {'ner': 26.223824573331967}
# Losses {'ner': 31.410957678105206}
# Losses {'ner': 35.350176085602016}
# Losses {'ner': 42.02340476740574}
# Losses {'ner': 47.690461524343846}
# Losses {'ner': 52.93165436138473}
# Losses {'ner': 62.673185375827174}
# Losses {'ner': 67.33659474303089}
# Losses {'ner': 75.34498307791613}
# Losses {'ner': 80.6702471369233}
# Losses {'ner': 4.453816309571266}
# Losses {'ner': 9.719140813453123}
# Losses {'ner': 13.484037764027455}
# Losses {'ner': 19.80825574893141}
# Losses {'ner': 26.249627998144554}
# Losses {'ner': 29.728654120046833}
# Losses {'ner': 37.39307555921767}
# Losses {'ner': 41.78863170014154}
# Losses {'ner': 47.73753696510028}
# Losses {'ner': 52.6619514446378}
# Losses {'ner': 62.21890499402287}
# Losses {'ner': 69.52736048359873}
# Losses {'ner': 72.20759748827402}
# Losses {'ner': 7.8206583466380835}
# Losses {'ner': 11.579944650628022}
# Losses {'ner': 18.086828659274033}
# Losses {'ner': 21.161096784635447}
# Losses {'ner': 25.6608250917634}
# Losses {'ner': 31.245230510248803}
# Losses {'ner': 34.862079046084546}
# Losses {'ner': 40.40634231240256}
# Losses {'ner': 47.044996797747444}
# Losses {'ner': 51.22154043171935}
# Losses {'ner': 55.91642303531438}
# Losses {'ner': 62.23597027128011}
# Losses {'ner': 70.43950046365529}
# Losses {'ner': 5.731219015782699}
# Losses {'ner': 9.186534980115539}
# Losses {'ner': 18.0633528025719}
# Losses {'ner': 25.74994931894662}
# Losses {'ner': 31.553021936899768}
# Losses {'ner': 35.06912087680803}
# Losses {'ner': 40.344221060257496}
# Losses {'ner': 46.69227813659245}
# Losses {'ner': 53.88408746300274}
# Losses {'ner': 61.50996834455714}
# Losses {'ner': 64.48715223840395}
# Losses {'ner': 69.16293570308903}
# Losses {'ner': 76.56293070225934}
# Losses {'ner': 5.940971895121038}
# Losses {'ner': 12.820849760435522}
# Losses {'ner': 17.685465412733578}
# Losses {'ner': 21.6491265488647}
# Losses {'ner': 28.372830678322174}
# Losses {'ner': 33.95361176866467}
# Losses {'ner': 39.14019116927997}
# Losses {'ner': 46.376716581754266}
# Losses {'ner': 53.0595393456741}
# Losses {'ner': 59.55046701582509}
# Losses {'ner': 68.11490667017537}
# Losses {'ner': 76.45424585195619}
# Losses {'ner': 85.25388170929986}
# Losses {'ner': 4.095858342945576}
# Losses {'ner': 10.780544028102668}
# Losses {'ner': 17.651394021189844}
# Losses {'ner': 22.194205154433646}
# Losses {'ner': 28.382132175060022}
# Losses {'ner': 34.835015274265814}
# Losses {'ner': 41.90891671893935}
# Losses {'ner': 49.05321533383706}
# Losses {'ner': 51.6541000745046}
# Losses {'ner': 55.480128816371646}
# Losses {'ner': 59.6623643143832}
# Losses {'ner': 66.71083313175787}
# Losses {'ner': 71.26822017008108}
# Losses {'ner': 3.906472386515836}
# Losses {'ner': 8.238387734236333}
# Losses {'ner': 13.546780208664153}
# Losses {'ner': 19.245801461526504}
# Losses {'ner': 25.598405435929386}
# Losses {'ner': 32.94009478415021}
# Losses {'ner': 41.13529310213992}
# Losses {'ner': 45.55480572889858}
# Losses {'ner': 50.05103361909344}
# Losses {'ner': 53.77905031715702}
# Losses {'ner': 58.647805105789054}
# Losses {'ner': 65.52162276058127}
# Losses {'ner': 71.1093199740969}
# Losses {'ner': 8.102256873506121}
# Losses {'ner': 14.826431074994616}
# Losses {'ner': 19.34748819723609}
# Losses {'ner': 26.492930444626836}
# Losses {'ner': 29.94199307009694}
# Losses {'ner': 39.13363654658315}
# Losses {'ner': 45.457297970337095}
# Losses {'ner': 52.56108598856372}
# Losses {'ner': 59.8082012727682}
# Losses {'ner': 64.6924057432334}
# Losses {'ner': 70.80450314496534}
# Losses {'ner': 76.81068703454343}
# Losses {'ner': 84.37868529480306}
# Losses {'ner': 4.629029733252537}
# Losses {'ner': 7.0241335468477075}
# Losses {'ner': 15.540240152377493}
# Losses {'ner': 20.845184207470567}
# Losses {'ner': 26.91032023778692}
# Losses {'ner': 31.65064210401991}
# Losses {'ner': 38.64013299498859}
# Losses {'ner': 40.96730366874638}
# Losses {'ner': 45.16569261405769}
# Losses {'ner': 49.988874366431475}
# Losses {'ner': 58.41621157519424}
# Losses {'ner': 64.82647737853134}
# Losses {'ner': 71.95315748445594}
# Losses {'ner': 7.96173357963562}
# Losses {'ner': 11.91160321411735}
# Losses {'ner': 16.45565387835086}
# Losses {'ner': 24.252003054054512}
# Losses {'ner': 31.69111614541105}
# Losses {'ner': 35.90446507291124}
# Losses {'ner': 42.03207617358492}
# Losses {'ner': 49.81834521250055}
# Losses {'ner': 52.47500621912257}
# Losses {'ner': 58.671971199225645}
# Losses {'ner': 67.19781452150272}
# Losses {'ner': 72.16109148007234}
# Losses {'ner': 79.50439262729486}
# Losses {'ner': 6.622149117290974}
# Losses {'ner': 11.821181039360454}
# Losses {'ner': 16.559802415131344}
# Losses {'ner': 18.829419953353522}
# Losses {'ner': 22.98608224426937}
# Losses {'ner': 28.427563054092047}
# Losses {'ner': 35.24632321072352}
# Losses {'ner': 41.162339431769965}
# Losses {'ner': 47.90370935726281}
# Losses {'ner': 55.44167006540414}
# Losses {'ner': 63.73213238048669}
# Losses {'ner': 72.69629133272286}
# Losses {'ner': 77.45055810141679}
# Losses {'ner': 4.2150741921796}
# Losses {'ner': 8.225841929815942}
# Losses {'ner': 12.3466896461141}
# Losses {'ner': 17.001334664859314}
# Losses {'ner': 24.47853512359177}
# Losses {'ner': 28.347344621565185}
# Losses {'ner': 36.26757319414935}
# Losses {'ner': 42.5690995171102}
# Losses {'ner': 49.57389128700777}
# Losses {'ner': 53.04383408773368}
# Losses {'ner': 59.75150766091168}
# Losses {'ner': 67.24457060413181}
# Losses {'ner': 73.10076936667531}
# Losses {'ner': 7.266721546649933}
# Losses {'ner': 13.615027457475662}
# Losses {'ner': 19.260332886129618}
# Losses {'ner': 28.122787538915873}
# Losses {'ner': 29.78821812597016}
# Losses {'ner': 33.893092653474014}
# Losses {'ner': 42.31840314598958}
# Losses {'ner': 49.27917628618161}
# Losses {'ner': 54.007506395938435}
# Losses {'ner': 59.29533835804705}
# Losses {'ner': 65.75539032208417}
# Losses {'ner': 74.70802533556798}
# Losses {'ner': 81.84945300524214}
# Losses {'ner': 4.965998048894107}
# Losses {'ner': 12.685578112490475}
# Losses {'ner': 16.744813494276286}
# Losses {'ner': 22.338730404074568}
# Losses {'ner': 27.946273998614515}
# Losses {'ner': 35.18232247852825}
# Losses {'ner': 40.81647509326535}
# Losses {'ner': 46.284306581964074}
# Losses {'ner': 54.35124957179028}
# Losses {'ner': 58.3315901960184}
# Losses {'ner': 62.18467451964284}
# Losses {'ner': 72.2105955663767}
# Losses {'ner': 79.91428281699086}
# Losses {'ner': 4.42106192175288}
# Losses {'ner': 8.750946983583162}
# Losses {'ner': 17.45997586835165}
# Losses {'ner': 26.156112700588892}
# Losses {'ner': 31.916870002432006}
# Losses {'ner': 35.37970481163666}
# Losses {'ner': 40.912056544356346}
# Losses {'ner': 49.51442331963062}
# Losses {'ner': 55.522109007954896}
# Losses {'ner': 60.8028301237764}
# Losses {'ner': 64.53133278476616}
# Losses {'ner': 71.5150890885534}
# Losses {'ner': 77.01573627392372}
# Losses {'ner': 6.9360142052173615}
# Losses {'ner': 14.674287762492895}
# Losses {'ner': 21.63885373994708}
# Losses {'ner': 25.086733041993284}
# Losses {'ner': 32.61825919031253}
# Losses {'ner': 35.669709658912325}
# Losses {'ner': 42.958449717086296}
# Losses {'ner': 47.83244853041742}
# Losses {'ner': 48.62797676520313}
# Losses {'ner': 56.53942992195334}
# Losses {'ner': 60.94087450067127}
# Losses {'ner': 65.1879621087628}
# Losses {'ner': 72.47625305643851}
# Losses {'ner': 6.792765647172928}
# Losses {'ner': 14.086410316333968}
# Losses {'ner': 21.50476720619281}
# Losses {'ner': 26.835611403843814}
# Losses {'ner': 32.68560465510791}
# Losses {'ner': 38.813952988869005}
# Losses {'ner': 43.48836011328285}
# Losses {'ner': 49.52835943852625}
# Losses {'ner': 53.452452627377056}
# Losses {'ner': 59.56494357939198}
# Losses {'ner': 63.580994034668834}
# Losses {'ner': 71.15015291657153}
# Losses {'ner': 78.18383238792273}
# Losses {'ner': 6.529397487640381}
# Losses {'ner': 11.266512910922756}
# Losses {'ner': 16.59937922944664}
# Losses {'ner': 22.33173161768127}
# Losses {'ner': 30.36383110307861}
# Losses {'ner': 36.94428579159785}
# Losses {'ner': 43.75551504664827}
# Losses {'ner': 49.678650886050946}
# Losses {'ner': 55.30071877248929}
# Losses {'ner': 61.38129465587781}
# Losses {'ner': 67.9917060020548}
# Losses {'ner': 75.2776860627514}
# Losses {'ner': 76.9343191230023}
# Losses {'ner': 6.724671823081735}
# Losses {'ner': 10.534424304314598}
# Losses {'ner': 17.047463434362726}
# Losses {'ner': 22.841627952955605}
# Losses {'ner': 27.35605976657098}
# Losses {'ner': 33.64794009326579}
# Losses {'ner': 36.61604723579512}
# Losses {'ner': 42.66873661024181}
# Losses {'ner': 49.87653856593613}
# Losses {'ner': 56.5820469344352}
# Losses {'ner': 60.276389611104946}
# Losses {'ner': 64.92088429899047}
# Losses {'ner': 69.03154081468563}
# Losses {'ner': 4.458981583291916}
# Losses {'ner': 12.612304431107532}
# Losses {'ner': 18.441516709235202}
# Losses {'ner': 25.948711446207653}
# Losses {'ner': 28.668023240124512}
# Losses {'ner': 35.33361846120616}
# Losses {'ner': 41.46710724223331}
# Losses {'ner': 46.43525566286817}
# Losses {'ner': 50.49059902257696}
# Losses {'ner': 56.515876955071604}
# Losses {'ner': 64.85845310893777}
# Losses {'ner': 71.13647892866587}
# Losses {'ner': 78.78076416049456}
# Losses {'ner': 3.0362425187133226}
# Losses {'ner': 11.338742707064}
# Losses {'ner': 18.992081146826592}
# Losses {'ner': 27.674744587530938}
# Losses {'ner': 31.737206633342055}
# Losses {'ner': 37.1904720022805}
# Losses {'ner': 46.709011878026274}
# Losses {'ner': 51.787119244364646}
# Losses {'ner': 58.12401812630668}
# Losses {'ner': 63.176946479791866}
# Losses {'ner': 69.28277811777042}
# Losses {'ner': 74.99852361964628}
# Losses {'ner': 79.77764491417844}
# Losses {'ner': 6.44343464076519}
# Losses {'ner': 13.312235403805971}
# Losses {'ner': 20.55308808758855}
# Losses {'ner': 29.87388177588582}
# Losses {'ner': 36.97911575064063}
# Losses {'ner': 44.42871281132102}
# Losses {'ner': 49.942221926059574}
# Losses {'ner': 55.67749787946206}
# Losses {'ner': 58.19249683232021}
# Losses {'ner': 64.53508765610695}
# Losses {'ner': 67.70453001433}
# Losses {'ner': 74.16785777416683}
# Losses {'ner': 81.21982427638162}
# Losses {'ner': 6.827774089308377}
# Losses {'ner': 10.741316750852537}
# Losses {'ner': 17.974447426905602}
# Losses {'ner': 26.178074017686516}
# Losses {'ner': 33.746038949545806}
# Losses {'ner': 40.631143426951354}
# Losses {'ner': 43.71574934102628}
# Losses {'ner': 48.156003321484064}
# Losses {'ner': 53.47475835284368}
# Losses {'ner': 60.79250803193227}
# Losses {'ner': 67.84067663153783}
# Losses {'ner': 72.63404579775525}
# Losses {'ner': 80.87043160515023}
# Losses {'ner': 4.916346370831889}
# Losses {'ner': 9.144639081445348}
# Losses {'ner': 17.144297546830785}
# Losses {'ner': 22.63159542450012}
# Losses {'ner': 27.164853208822024}
# Losses {'ner': 31.41888461367489}
# Losses {'ner': 35.518219196361315}
# Losses {'ner': 41.537516370706726}
# Losses {'ner': 43.46776408559526}
# Losses {'ner': 47.784770066296915}
# Losses {'ner': 50.804353268658815}
# Losses {'ner': 56.11660198935897}
# Losses {'ner': 60.805432193667}
# Losses {'ner': 3.953267271052656}
# Losses {'ner': 10.74546084393359}
# Losses {'ner': 16.626082700477756}
# Losses {'ner': 22.59305304920844}
# Losses {'ner': 25.00895613446909}
# Losses {'ner': 29.850882016272127}
# Losses {'ner': 37.74953725203949}
# Losses {'ner': 40.10430189871175}
# Losses {'ner': 47.03860247039182}
# Losses {'ner': 56.421209811204506}
# Losses {'ner': 63.451991251517654}
# Losses {'ner': 67.69569731731173}
# Losses {'ner': 74.02553381253239}
# Losses {'ner': 5.077194483397761}
# Losses {'ner': 10.432045405208058}
# Losses {'ner': 17.32590845939872}
# Losses {'ner': 25.48267372665164}
# Losses {'ner': 31.239877537858277}
# Losses {'ner': 38.053384275209694}
# Losses {'ner': 44.415256486308365}
# Losses {'ner': 48.977959107176005}
# Losses {'ner': 55.00540376882914}
# Losses {'ner': 61.799189050745056}
# Losses {'ner': 68.9761115806809}
# Losses {'ner': 76.83921833808331}
# Losses {'ner': 79.94442826403863}
# Losses {'ner': 6.233592584729195}
# Losses {'ner': 16.15181066095829}
# Losses {'ner': 22.56482708290423}
# Losses {'ner': 28.883864838855516}
# Losses {'ner': 33.65634910765402}
# Losses {'ner': 41.54406233134978}
# Losses {'ner': 44.30852890041024}
# Losses {'ner': 51.30174438488814}
# Losses {'ner': 58.29254369271132}
# Losses {'ner': 63.70665325057837}
# Losses {'ner': 68.7967218101918}
# Losses {'ner': 74.09362651565664}
# Losses {'ner': 79.14415248798525}
# Losses {'ner': 3.9820837008828676}
# Losses {'ner': 9.692606014485136}
# Losses {'ner': 14.690721011540518}
# Losses {'ner': 20.43137978023333}
# Losses {'ner': 25.80195372138587}
# Losses {'ner': 31.96373494301406}
# Losses {'ner': 39.16586106975046}
# Losses {'ner': 44.906837824268905}
# Losses {'ner': 51.156956088583}
# Losses {'ner': 54.71445593046087}
# Losses {'ner': 57.97496255908504}
# Losses {'ner': 64.35757293973461}
# Losses {'ner': 71.36616804872051}
# Losses {'ner': 6.333020240068436}
# Losses {'ner': 13.367544442415237}
# Losses {'ner': 14.74098359776508}
# Losses {'ner': 21.783969245681874}
# Losses {'ner': 27.93238385749828}
# Losses {'ner': 35.95691822068147}
# Losses {'ner': 42.559977853385135}
# Losses {'ner': 46.25431380544069}
# Losses {'ner': 52.02169272799256}
# Losses {'ner': 56.55698415321149}
# Losses {'ner': 63.7013425646428}
# Losses {'ner': 67.71416596026302}
# Losses {'ner': 75.92398778052211}
# Losses {'ner': 4.237140882265521}
# Losses {'ner': 9.174993312437437}
# Losses {'ner': 15.181123323258362}
# Losses {'ner': 20.47889791392663}
# Losses {'ner': 28.136953830355196}
# Losses {'ner': 34.9259242372209}
# Losses {'ner': 36.7149219847804}
# Losses {'ner': 45.26829545195028}
# Losses {'ner': 47.80160667852772}
# Losses {'ner': 53.95847977803362}
# Losses {'ner': 60.672168984201676}
# Losses {'ner': 66.742719919487}
# Losses {'ner': 72.58809454456497}
# Losses {'ner': 7.270945728712832}
# Losses {'ner': 12.859340817623888}
# Losses {'ner': 19.21963813873299}
# Losses {'ner': 27.2444338017021}
# Losses {'ner': 33.20269845806702}
# Losses {'ner': 42.344406802288134}
# Losses {'ner': 46.474458934542284}
# Losses {'ner': 52.21271128432109}
# Losses {'ner': 60.26294926778628}
# Losses {'ner': 65.24845447476237}
# Losses {'ner': 69.14056570912926}
# Losses {'ner': 75.85080044056504}
# Losses {'ner': 78.81478759722798}
# Losses {'ner': 3.774670539307408}
# Losses {'ner': 6.645237480697688}
# Losses {'ner': 14.295678145211241}
# Losses {'ner': 19.51710509976033}
# Losses {'ner': 26.465806921027934}
# Losses {'ner': 32.57274593880061}
# Losses {'ner': 37.714149507592765}
# Losses {'ner': 40.962322741973935}
# Losses {'ner': 43.92494511759162}
# Losses {'ner': 52.366259576438665}
# Losses {'ner': 56.196636554420024}
# Losses {'ner': 60.86450602175256}
# Losses {'ner': 67.46042507575413}
# Losses {'ner': 2.9289451978609335}
# Losses {'ner': 6.652448506504491}
# Losses {'ner': 12.65703212231417}
# Losses {'ner': 19.631096723975837}
# Losses {'ner': 25.78946675688237}
# Losses {'ner': 30.57864408773346}
# Losses {'ner': 36.07610739765621}
# Losses {'ner': 44.18696232138134}
# Losses {'ner': 50.686032414417035}
# Losses {'ner': 56.55583268681473}
# Losses {'ner': 59.34139433701855}
# Losses {'ner': 64.07105669168263}
# Losses {'ner': 67.6037152286211}
# Losses {'ner': 10.423923909664154}
# Losses {'ner': 15.262047642072083}
# Losses {'ner': 22.57775264715159}
# Losses {'ner': 30.644597137593713}
# Losses {'ner': 35.19810837531933}
# Losses {'ner': 40.513207638913094}
# Losses {'ner': 42.623777030243595}
# Losses {'ner': 50.14121428117907}
# Losses {'ner': 54.802079930127015}
# Losses {'ner': 62.4614242009524}
# Losses {'ner': 66.70194757804111}
# Losses {'ner': 73.13490011617378}
# Losses {'ner': 77.69567588207869}
# Losses {'ner': 5.046622575770016}
# Losses {'ner': 12.253267386506195}
# Losses {'ner': 16.15482297683775}
# Losses {'ner': 22.075791032562847}
# Losses {'ner': 27.168140461246367}
# Losses {'ner': 33.00794613691687}
# Losses {'ner': 37.884389460479724}
# Losses {'ner': 45.498122059201705}
# Losses {'ner': 53.14268255273055}
# Losses {'ner': 60.67221151725971}
# Losses {'ner': 65.5274185249375}
# Losses {'ner': 73.33953085632788}
# Losses {'ner': 79.51579675448852}
# Losses {'ner': 5.000318961756761}
# Losses {'ner': 13.91105894984537}
# Losses {'ner': 17.511517146029632}
# Losses {'ner': 27.46232465783612}
# Losses {'ner': 33.67853909859912}
# Losses {'ner': 40.602713886075776}
# Losses {'ner': 44.85212812701718}
# Losses {'ner': 49.75974662087455}
# Losses {'ner': 55.38973589184306}
# Losses {'ner': 60.84629894330678}
# Losses {'ner': 67.07286244913516}
# Losses {'ner': 74.45070128190159}
# Losses {'ner': 82.41031870293259}
# Losses {'ner': 6.846764141693711}
# Losses {'ner': 13.230526374652982}
# Losses {'ner': 21.23141151766322}
# Losses {'ner': 28.285409138603427}
# Losses {'ner': 36.30363373558066}
# Losses {'ner': 40.25585294601292}
# Losses {'ner': 46.481464045828446}
# Losses {'ner': 49.96696882951842}
# Losses {'ner': 56.02923996863724}
# Losses {'ner': 60.87160412339331}
# Losses {'ner': 67.62272642261611}
# Losses {'ner': 72.3041477919303}
# Losses {'ner': 77.8196326318479}
# Losses {'ner': 9.154270589351654}
# Losses {'ner': 13.254899002611637}
# Losses {'ner': 19.33973963857352}
# Losses {'ner': 25.308415897718078}
# Losses {'ner': 30.405834198340017}
# Losses {'ner': 37.41177600656374}
# Losses {'ner': 42.27257415686472}
# Losses {'ner': 51.55448275838717}
# Losses {'ner': 56.60306959819718}
# Losses {'ner': 61.70521207438287}
# Losses {'ner': 68.13466232554492}
# Losses {'ner': 74.56110912100849}
# Losses {'ner': 81.49672585265216}
# Losses {'ner': 6.1300913244485855}
# Losses {'ner': 14.163052335381508}
# Losses {'ner': 19.421667531132698}
# Losses {'ner': 27.931082025170326}
# Losses {'ner': 33.633974919095635}
# Losses {'ner': 41.113394126994535}
# Losses {'ner': 48.79433736554347}
# Losses {'ner': 54.166962802410126}
# Losses {'ner': 58.89943063810733}
# Losses {'ner': 66.98770816430715}
# Losses {'ner': 74.93973816365269}
# Losses {'ner': 79.03024410635498}
# Losses {'ner': 85.44374319297731}

# %%
for text, _ in train:
    doc = nlp(text)
    print("Entities",[(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('fraud', 'ACTIVITY'), ('credit card', 'PRODUCT')]
# Entities [('charges', 'ACTIVITY'), ('Investment account', 'PRODUCT')]
# Entities [('open', 'ACTIVITY'), ('load account', 'PRODUCT')]
# Entities [('opening', 'ACTIVITY'), ('savings account', 'PRODUCT')]
# Entities [('loan account', 'PRODUCT'), ('not approved', 'ACTIVITY'), ('funded', 'PRODUCT')]
# Entities [('payment', 'ACTIVITY'), ('credit card', 'PRODUCT')]
# Entities [('credit', 'PRODUCT'), ('past due', 'ACTIVITY')]
# Entities [('payment', 'ACTIVITY'), ('card', 'PRODUCT')]
# Entities [('charges', 'ACTIVITY'), ('credit card', 'PRODUCT')]
# Entities [('checking account', 'PRODUCT')]
# Entities [('open', 'ACTIVITY'), ('loan account', 'PRODUCT')]
# Entities [('mortgage', 'PRODUCT'), ('delinquent', 'ACTIVITY')]
# Entities [('balance', 'ACTIVITY'), ('savings account', 'PRODUCT')]

# %%
from spacy import displacy

# %%
doc = nlp("what is the process to open a new savings account")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# open 23 27 ACTIVITY
# savings account 34 49 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what is the process to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  a new
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     savings account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
doc = nlp("My credit card payment will be delayed")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# credit card 3 14 PRODUCT
# payment 15 22 ACTIVITY
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     credit card
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  will be delayed</div></span>

# %%
doc = nlp("I lost my investment account password and cannot open my account now")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# investment account 10 28 PRODUCT
# account now 57 68 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I lost my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     investment account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  password and cannot open my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     account now
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
doc = nlp("What is the status of my loan account")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# loan account 25 37 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">What is the status of my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     loan account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
doc = nlp('Australia wants to force Facebook and Goolge to pay media companies for news')
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Australia wants to force Facebook and Goolge to pay media companies for news</div></span>

# %% [markdown]
# https://explosion.ai/blog/pseudo-rehearsal-catastrophic-forgetting

# %%
doc = nlp('I do not have money to pay my credit card account')
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# credit card 30 41 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I do not have money to pay my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     credit card
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  account</div></span>

# %%
doc = nlp('what is the process to open a new savings account')
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# open 23 27 ACTIVITY
# savings account 34 49 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what is the process to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  a new
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     savings account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
doc = nlp("What are the charges on credit card late payment in Bank of America")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# charges 13 20 ACTIVITY
# payment 41 48 ACTIVITY
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">What are the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     charges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  on credit card late
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  in Bank of America</div></span>
